# %% [markdown]
# # Import the dataset into python

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('mushrooms.csv')
data
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %% [markdown]
# ### checking for null values

# %%
data.isna().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
data.shape
# Out:
# (8124, 23)

# %% [markdown]
# ## Label Encoding

# %%
data.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
data['class']=encoder.fit_transform(data['class'])
data['cap-shape']=encoder.fit_transform(data['cap-shape'])
data['cap-surface']=encoder.fit_transform(data['cap-surface'])
data['cap-color']=encoder.fit_transform(data['cap-color'])
data['bruises']=encoder.fit_transform(data['bruises'])
data['odor']=encoder.fit_transform(data['odor'])
data['gill-attachment']=encoder.fit_transform(data['gill-attachment'])
data['gill-spacing']=encoder.fit_transform(data['gill-spacing'])
data['gill-size']=encoder.fit_transform(data['gill-size'])
data['gill-color']=encoder.fit_transform(data['gill-color'])
data['stalk-shape']=encoder.fit_transform(data['stalk-shape'])
data['stalk-root']=encoder.fit_transform(data['stalk-root'])
data['stalk-surface-above-ring']=encoder.fit_transform(data['stalk-surface-above-ring'])
data['stalk-surface-below-ring']=encoder.fit_transform(data['stalk-surface-below-ring'])
data['stalk-color-above-ring']=encoder.fit_transform(data['stalk-color-above-ring'])
data['stalk-color-below-ring']=encoder.fit_transform(data['stalk-color-below-ring'])
data['veil-type']=encoder.fit_transform(data['veil-type'])
data['veil-color']=encoder.fit_transform(data['veil-color'])
data['ring-number']=encoder.fit_transform(data['ring-number'])
data['ring-type']=encoder.fit_transform(data['ring-type'])
data['spore-print-color']=encoder.fit_transform(data['spore-print-color'])
data['population']=encoder.fit_transform(data['population'])
data['habitat']=encoder.fit_transform(data['habitat'])

# %%
data
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %% [markdown]
# ### Correlation matrix

# %%
corrmatr=data.corr()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.subplots(figsize=(14,10))
sns.heatmap(corrmatr,annot=True,linewidth=0.1,cmap='Greens')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Splitting the dataset for training and testing

# %%
X=data.drop(['class'],axis=1)
y=pd.DataFrame(data['class'])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %% [markdown]
# ## ML Algorithm to predict the mashroom is edible or not(SVM)

# %%
from sklearn.svm import SVC
svn=SVC()
model=svn.fit(X_train,y_train)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
print(data.loc[[1]])

# %%
cpsh=int(input('enter value for cap-shape:'))
cpsu=int(input('enter value for cap-surface:'))
cpcl=int(input('enter value for cap-color:'))
bru=int(input('enter value for bruises:'))
odo=int(input('enter value for odor:'))
giat=int(input('enter value for gill-attachment:'))
gisp=int(input('enter value for gill-spacing:'))
gisi=int(input('enter value for gill-size:'))
gico=int(input('enter value for gill-color:'))
stsh=int(input('enter value for stalk-shape:'))
stro=int(input('enter value for stalk-root:'))
stsu=int(input('enter value for stalk-surface-above-ring:'))
stsb=int(input('enter value for stalk-surface-below-ring:'))
stco=int(input('enter value for stalk-color-above-ring:'))
stcb=int(input('enter value for stalk-color-below-ring:'))
vety=int(input('enter value for veil-type:'))
vrco=int(input('enter value for veil-color:'))
rinu=int(input('enter value for ring-number:'))
rity=int(input('enter value for ring-type:'))
sppr=int(input('enter value for spore-print-color:'))
pop=int(input('enter value for population:'))
hab=int(input('enter value for habitat:'))
# Out:
# enter value for cap-shape:1
# enter value for cap-surface:5
# enter value for cap-color:2
# enter value for bruises:4
# enter value for odor:1
# enter value for gill-attachment:6
# enter value for gill-spacing:1
# enter value for gill-size:0
# enter value for gill-color:1
# enter value for stalk-shape:4
# enter value for stalk-root:2
# enter value for stalk-surface-above-ring:1
# enter value for stalk-surface-below-ring:2
# enter value for stalk-color-above-ring:7
# enter value for stalk-color-below-ring:7
# enter value for veil-type:0
# enter value for veil-color:2
# enter value for ring-number:1
# enter value for ring-type:4
# enter value for spore-print-color:2
# enter value for population:3
# enter value for habitat:5

# %%
x_new=[cpsh,cpsu,cpcl,bru,odo,giat,gisp,gisi,gico,stsh,stro,stsu,stsb,stco,stcb,vety,vrco,rinu,rity,sppr,pop,hab]
x_new=np.reshape(x_new,(1,-1))
result=svn.predict(x_new)

if(result==0):
    print('the mashroom is edible')
else:
    print('the mashroom is poisonous')
# Out:
# the mashroom is poisonous

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
X_train=ss.fit_transform(X_train)
X_test=ss.fit_transform(X_test)

# %% [markdown]
# # Naive Bayes Classifier

# %% [markdown]
# ## i) Fitting Guassian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(X_train,y_train)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# GaussianNB()

# %% [markdown]
# ## Predicting the test result

# %%
y_pred=gnb.predict(X_test)

# %% [markdown]
# ## Confusion matrix and Accuracy Score

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
cm=confusion_matrix(y_test,y_pred)
acc=accuracy_score(y_test,y_pred)
cm
# Out:
# array([[958,  82],
#        [ 69, 922]], dtype=int64)

# %%
acc
# Out:
# 0.9256523879862137

# %% [markdown]
# ## ii) Bernoulli Naive Bayes

# %%
from sklearn.naive_bayes import BernoulliNB
bnb=BernoulliNB()
bnb.fit(X_train,y_train)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# BernoulliNB()

# %% [markdown]
# ### Predicting the test result

# %%
y_pred=bnb.predict(X_test)

# %% [markdown]
# ## Confusion matrix and Accuracy Score

# %%
cm1=confusion_matrix(y_test,y_pred)
acc1=accuracy_score(y_test,y_pred)
cm1
# Out:
# array([[1012,   28],
#        [ 181,  810]], dtype=int64)

# %%
acc1
# Out:
# 0.897095027080256

# %% [markdown]
# #### Here Guassian naive bayes is more acurate than Bernoulli naive bayes
